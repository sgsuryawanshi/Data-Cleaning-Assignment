# %%
#Solution Q1. Create a new attribute called 'Tag' and it should contain the letters between (*) from  'Country'
import re
import numpy as np
import pandas as pd
#how to rename columns and/or skip rows that we don't want to consider
#loading our data
olympics_df = pd.read_csv('olympics.csv', header=1)
new_names =  {'Unnamed: 0': 'Country',
              '? Summer': 'Summer Olympics',
              '01 !': 'Gold',
              '02 !': 'Silver',
              '03 !': 'Bronze',
              '? Winter': 'Winter Olympics',
              '01 !.1': 'Gold.1',
              '02 !.1': 'Silver.1',
              '03 !.1': 'Bronze.1',
              '? Games': '# Games',
              '01 !.2': 'Gold.2',
              '02 !.2': 'Silver.2',
              '03 !.2': 'Bronze.2'}
olympics_df.rename(columns=new_names, inplace=True)#our new names
olympics_df.rename(columns={'Country':'Tag'}, inplace=True)
#again strings are a problem for us
#this functions will help us to extract the city-state of our region name
#create another function to retrieve the Universty Name and add a new atribute to towns_df

olympics_df['Tag']=olympics_df['Tag'].str.findall(r"\(\w{3}\)")

dd=olympics_df['Tag'].str[0]
dd=dd.str[1:-1]
olympics_df["Tag"]=pd.DataFrame(dd)
olympics_df1=olympics_df
olympics_df1
# Out:
#      Tag  Summer Olympics  Gold  Silver  Bronze  Total  Winter Olympics  \
# 0    AFG               13     0       0       2      2                0
# 1    ALG               12     5       2       8     15                3
# 2    ARG               23    18      24      28     70               18
# 3    ARM                5     1       2       9     12                6
# 4    ANZ                2     3       4       5     12                0
# 5    AUS               25   139     152     177    468               18
# 6    AUT               26    18      33      35     86               22
# 7    AZE                5     6       5      15     26                5
# 8    BAH               15     5       2       5     12                0
# 9    BRN                8     0       0       1      1                0
# 10   BAR               11     0       0       1      1                0
# 11   BLR                5    12      24      39     75                6
# ...

# %%
#Solution Q2. Alter the values of 'Country' so it just contains the actual names of the countries
import re
import numpy as np
import pandas as pd

#how to rename columns and/or skip rows that we don't want to consider
#loading our data
olympics_df = pd.read_csv('olympics.csv',header=1)
new_names =  {'Unnamed: 0': 'Country','? Summer': 'Summer Olympics','01 !': 'Gold','02 !': 'Silver','03 !': 'Bronze',
              '? Winter': 'Winter Olympics','01 !.1': 'Gold.1','02 !.1': 'Silver.1','03 !.1': 'Bronze.1','? Games': '# Games',
              '01 !.2': 'Gold.2','02 !.2': 'Silver.2','03 !.2': 'Bronze.2'}
olympics_df.rename(columns=new_names, inplace=True)#our new names
olympics_df.head()

c = []
for i in range (0, len(olympics_df)):
    c.append(olympics_df['Country'][i].split(" ")[0])
c
olympics_df['Country']=pd.DataFrame(c)
olympics_df
# Out:
#          Country  Summer Olympics  Gold  Silver  Bronze  Total  \
# 0    Afghanistan               13     0       0       2      2
# 1        Algeria               12     5       2       8     15
# 2      Argentina               23    18      24      28     70
# 3        Armenia                5     1       2       9     12
# 4    Australasia                2     3       4       5     12
# 5      Australia               25   139     152     177    468
# 6        Austria               26    18      33      35     86
# 7     Azerbaijan                5     6       5      15     26
# 8        Bahamas               15     5       2       5     12
# 9        Bahrain                8     0       0       1      1
# 10      Barbados               11     0       0       1      1
# 11       Belarus                5    12      24      39     75
# 12       Belgium               25    37      52      53    142
# 13       Bermuda               17     0       0       1      1
# ...

# %%
#Solution Q3 Create a new dataframe only containing only the following attributes: 'Tag', 'summer olympics' and 'winter olympics'.
 #3.1. In addition, it should also contain 'combined Total', which has to be calculated using the sum of 'summmer olympics' and 'winter olympics'
import re   
import numpy as np
import pandas as pd
#how to rename columns and/or skip rows that we don't want to consider
#loading our data
olympics_df = pd.read_csv('olympics.csv', header=1)
new_names =  {'Unnamed: 0': 'Country',
              '? Summer': 'Summer Olympics',
              '01 !': 'Gold',
              '02 !': 'Silver',
              '03 !': 'Bronze',
              '? Winter': 'Winter Olympics',
              '01 !.1': 'Gold.1',
              '02 !.1': 'Silver.1',
              '03 !.1': 'Bronze.1',
              '? Games': '# Games',
              '01 !.2': 'Gold.2',
              '02 !.2': 'Silver.2',
              '03 !.2': 'Bronze.2'}
olympics_df.rename(columns=new_names, inplace=True)#our new names
olympics_df.rename(columns={'Country':'Tag'}, inplace=True)
to_drop = ['Gold','Silver','Bronze','Gold.1','Total','Silver.1','Bronze.1','# Games','Gold.2','Silver.2','Bronze.2','Total.1']
olympics_df.drop(to_drop, inplace=True, axis=1)
olympics_df['Combined total']=olympics_df['Summer Olympics']+ olympics_df['Winter Olympics']#Combined total is of both the winter and summer olympics.
#add data frames winter +summer olympics
c = []
for i in range (0, len(olympics_df)):
    c.append(olympics_df['Tag'][i].split(" ")[0])
c
olympics_df['Tag']=pd.DataFrame(c)
olympics_df.head(20)
# Out:
#             Tag  Summer Olympics  Winter Olympics  Combined total
# 0   Afghanistan               13                0              13
# 1       Algeria               12                3              15
# 2     Argentina               23               18              41
# 3       Armenia                5                6              11
# 4   Australasia                2                0               2
# 5     Australia               25               18              43
# 6       Austria               26               22              48
# 7    Azerbaijan                5                5              10
# 8       Bahamas               15                0              15
# 9       Bahrain                8                0               8
# 10     Barbados               11                0              11
# 11      Belarus                5                6              11
# 12      Belgium               25               20              45
# ...
